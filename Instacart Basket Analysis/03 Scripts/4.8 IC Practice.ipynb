# %% [markdown]
# # Grouping/Aggregating Walkthrough

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#import data
path = '/Users/kimballwightman/Documents/CareerFoundry/Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_derive.pkl'))

# %%
#create a subset
df = ords_prods_merge[:1000000]

# %%
df.head()
# Out:
#    order_id  user_id  user_order_num  order_day_of_week  order_hour_of_day  \
# 0   2539329        1               1                  2                  8
# 1   2398795        1               2                  3                  7
# 2    473747        1               3                  3                 12
# 3   2254736        1               4                  4                  7
# 4    431534        1               5                  4                 15
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                    15.0        False         196                  1
# 2                    21.0        False         196                  1
# 3                    29.0        False         196                  1
# 4                    28.0        False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
df.shape
# Out:
# (1000000, 19)

# %%
#1) split the data into groups
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'user_order_num': ['mean']})
# Out:
#               user_order_num
#                         mean
# department_id
# 4                  18.830221
# 7                  17.521447
# 13                 18.017099
# 14                 19.244903
# 16                 19.469166
# 17                 11.228785
# 19                 19.320948
# 20                 17.694040

# %%
df.groupby('department_id').agg({'user_order_num': ['mean','min','max']})
# Out:
#               user_order_num
#                         mean min max
# department_id
# 4                  18.830221   1  99
# 7                  17.521447   1  99
# 13                 18.017099   1  99
# 14                 19.244903   1  99
# 16                 19.469166   1  99
# 17                 11.228785   1  98
# 19                 19.320948   1  99
# 20                 17.694040   1  99

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['user_order_num'].transform(np.max)

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  user_order_num  order_day_of_week  order_hour_of_day  \
# 0    2539329        1               1                  2                  8
# 1    2398795        1               2                  3                  7
# 2     473747        1               3                  3                 12
# 3    2254736        1               4                  4                  7
# 4     431534        1               5                  4                 15
# 5    3367565        1               6                  2                  7
# 6     550135        1               7                  1                  9
# 7    3108588        1               8                  1                 14
# 8    2295261        1               9                  1                 16
# 9    2550362        1              10                  4                  8
# 10   2968173       15              15                  1                  9
# ...

# %%
pd.options.display.max_rows = None

# %%
#create flag
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal Customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular Customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New Customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular Customer    15719388
# Loyal Customer      10187688
# New Customer         6182747
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id','loyalty_flag','user_order_num']].head(60)
# Out:
#     user_id      loyalty_flag  user_order_num
# 0         1      New Customer               1
# 1         1      New Customer               2
# 2         1      New Customer               3
# 3         1      New Customer               4
# 4         1      New Customer               5
# 5         1      New Customer               6
# 6         1      New Customer               7
# 7         1      New Customer               8
# 8         1      New Customer               9
# 9         1      New Customer              10
# 10       15  Regular Customer              15
# 11       15  Regular Customer              17
# 12       15  Regular Customer              18
# 13       15  Regular Customer              21
# 14       15  Regular Customer              22
# 15       19      New Customer               2
# 16       19      New Customer               5
# 17       19      New Customer               7
# 18       21  Regular Customer              10
# ...
